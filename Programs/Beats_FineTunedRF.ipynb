# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
submission = pd.read_csv('sample_submission.csv')

# %% [markdown]
# # Define features

# %%
features = ['RhythmScore', 'AudioLoudness', 'VocalContent', 'AcousticQuality', 
            'InstrumentalScore', 'LivePerformanceLikelihood', 'MoodScore', 
            'TrackDurationMs', 'Energy']
X = train[features]
y = train['BeatsPerMinute']
X_test = test[features]

# %% [markdown]
# # Feature engineering: Log-transform skewed features

# %%
X['AudioLoudness'] = np.log1p(-X['AudioLoudness'])
X_test['AudioLoudness'] = np.log1p(-X_test['AudioLoudness'])
X['TrackDurationMs'] = np.log1p(X['TrackDurationMs'])
X_test['TrackDurationMs'] = np.log1p(X_test['TrackDurationMs'])
# Out:
# C:\Users\nishi\AppData\Local\Temp\ipykernel_21068\3028610528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['AudioLoudness'] = np.log1p(-X['AudioLoudness'])
# C:\Users\nishi\AppData\Local\Temp\ipykernel_21068\3028610528.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['AudioLoudness'] = np.log1p(-X_test['AudioLoudness'])
# C:\Users\nishi\AppData\Local\Temp\ipykernel_21068\3028610528.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['TrackDurationMs'] = np.log1p(X['TrackDurationMs'])
# C:\Users\nishi\AppData\Local\Temp\ipykernel_21068\3028610528.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['TrackDurationMs'] = np.log1p(X_test['TrackDurationMs'])

# %% [markdown]
# # Standardize features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Split data

# %%
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Fine-tuned GridSearchCV

# %%
param_grid = {
    'n_estimators': [140, 150, 160],
    'max_depth': [9, 10, 11],
    'min_samples_split': [4, 5, 6]
}
rf = RandomForestRegressor(random_state=42, n_jobs=-1)
grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='neg_root_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [9, 10, 11],
#                          'min_samples_split': [4, 5, 6],
#                          'n_estimators': [140, 150, 160]},
#              scoring='neg_root_mean_squared_error')

# %% [markdown]
# # Best parameters and score

# %%
print(f"Best Parameters: {grid_search.best_params_}")
best_rf = grid_search.best_estimator_
cv_rmse = -grid_search.best_score_
print(f"Best CV RMSE: {cv_rmse:.4f}")
# Out:
# Best Parameters: {'max_depth': 9, 'min_samples_split': 5, 'n_estimators': 160}
# Best CV RMSE: 26.4666

# %% [markdown]
# # Validate on holdout set

# %%
rf_pred = best_rf.predict(X_val)
rf_rmse = np.sqrt(mean_squared_error(y_val, rf_pred))
print(f"Validation RMSE: {rf_rmse:.4f}")
# Out:
# Validation RMSE: 26.4386

# %% [markdown]
# # Feature Importance

# %%
importances = best_rf.feature_importances_
feature_names = features
plt.figure(figsize=(10, 6))
plt.bar(feature_names, importances)
plt.title('Feature Importance in Random Forest')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Generate test predictions

# %%
test_pred = best_rf.predict(X_test_scaled)
submission['BeatsPerMinute'] = test_pred
submission.to_csv('submission_rf_finetuned.csv', index=False)
print("Submission file created: submission_rf_finetuned.csv")
# Out:
# Submission file created: submission_rf_finetuned.csv
